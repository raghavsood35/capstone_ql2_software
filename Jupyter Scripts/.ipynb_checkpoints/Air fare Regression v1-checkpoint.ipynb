# %% [markdown]
# # Regression task for the data sent earlier by ql2

# %%
# all imports
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from math import sqrt
# machine learning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import linear_model

# %%
# Reading data
# airfare_data = pd.read_csv("airfare_lax_2019_initial.csv", delimiter=",")
airfare_data = pd.read_csv("../Data/Airfare data with day_of_week.csv", delimiter=",")
airfare_data.rename(columns = {"EXTRACT(WEEK FROM DDATE)" : "week", "DAYOFWEEK(DDATE)" : "dayofweek" ,
                              "AVG(FARE)": "average", "MIN(FARE)": "min", "MAX(FARE)": "max", 
                               "MEDIAN(FARE)" : "median", "STDDEV(FARE)" : "stddev"} , inplace = True)
airport_distance_data = pd.read_csv("../Data/distance_between_airports.csv", delimiter=",")

# %%
airfare_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344666 entries, 0 to 344665
# Data columns (total 10 columns):
# TO_AIRPORT      344666 non-null object
# CXR             344666 non-null object
# FROM_AIRPORT    344666 non-null object
# week            344666 non-null int64
# dayofweek       344666 non-null int64
# average         344666 non-null float64
# min             344666 non-null float64
# max             344666 non-null float64
# median          344666 non-null float64
# stddev          341659 non-null float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 26.3+ MB

# %%
weekdays = [1,2,3,4]
airfare_data["weekend"] = np.where(airfare_data["dayofweek"].isin(weekdays) == True, 0, 1)

# %%
airfare_data.head()
# Out:
#   TO_AIRPORT CXR FROM_AIRPORT  week  dayofweek  average    min    max  median  \
# 0        ADQ  AS          ANC     1          0   213.25  109.0  362.0   191.0
# 1        ADQ  AS          ANC     1          2   300.25  170.0  462.0   313.5
# 2        ADQ  AS          ANC     1          3   262.00  158.0  462.0   170.0
# 3        ADQ  AS          ANC     1          4   252.00  126.0  362.0   260.0
# 4        ADQ  AS          ANC     1          5   294.00  126.0  462.0   362.0
#
#        stddev  weekend
# 0  101.647500        1
# 1  109.914946        0
# 2  141.506184        0
# 3  118.215300        0
# 4  136.782065        1

# %% [markdown]
# ## Merging distance

# %%
airport_distance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379625 entries, 0 to 379624
# Data columns (total 3 columns):
# AIRPORT_FROM    379625 non-null object
# AIRPORT_TO      379625 non-null object
#  MILES          379625 non-null object
# dtypes: object(3)
# memory usage: 8.7+ MB

# %%
airfare_data = pd.merge(airfare_data, airport_distance_data, how = "left", left_on = ["FROM_AIRPORT", "TO_AIRPORT"]
                  , right_on = ["AIRPORT_FROM", "AIRPORT_TO"])

# Dropping unnecessary columns
airfare_data.drop(columns = ["AIRPORT_FROM", "AIRPORT_TO"], axis=1, inplace = True)

# Renaming Miles column
airfare_data.rename(columns = {" MILES " : "miles"} , inplace = True)

# Removing comma and extra space from each entry in miles
airfare_data["miles"] = airfare_data["miles"].apply(lambda x : x.replace(",", "").strip())

# Converting to numeric
airfare_data["miles"] = pd.to_numeric(airfare_data["miles"])

# Adding price/mile column
airfare_data["price_per_mile"] = airfare_data["average"] / airfare_data["miles"]

# %%
airfare_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 357808 entries, 0 to 357807
# Data columns (total 13 columns):
# TO_AIRPORT        357808 non-null object
# CXR               357808 non-null object
# FROM_AIRPORT      357808 non-null object
# week              357808 non-null int64
# dayofweek         357808 non-null int64
# average           357808 non-null float64
# min               357808 non-null float64
# max               357808 non-null float64
# median            357808 non-null float64
# stddev            354712 non-null float64
# weekend           357808 non-null int64
# miles             357808 non-null int64
# price_per_mile    357808 non-null float64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 38.2+ MB

# %% [markdown]
# ## Restricting to LAX

# %%
lax_data = airfare_data[airfare_data["TO_AIRPORT"] == "LAX"]
lax_data.head()
# Out:
#        TO_AIRPORT CXR FROM_AIRPORT  week  dayofweek     average    min    max  \
# 156132        LAX  AS          JFK     1          0  278.100000  243.0  429.0
# 156133        LAX  AS          JFK     1          2  465.266667  392.0  697.0
# 156134        LAX  AS          JFK     1          3  454.200000  367.0  697.0
# 156135        LAX  AS          JFK     1          4  326.000000  209.0  429.0
# 156136        LAX  AS          JFK     1          5  282.600000  209.0  392.0
#
#         median      stddev  weekend  miles  price_per_mile
# 156132   243.0   66.108413        1   2469        0.112637
# 156133   472.0   72.132286        0   2469        0.188443
# 156134   392.0  120.372385        0   2469        0.183961
# 156135   319.0   73.025110        0   2469        0.132037
# 156136   284.0   49.279701        1   2469        0.114459

# %% [markdown]
# ## How we interpret features?
#
# TO_AIRPORT -> DROP
#
# CXR -> convert to numerical (1 hot encoding for now)
#
# FROM_AIPORT -> convert to numerical (1 hot encoding for now)
#
# week -> convert to numerical (1 hot encoding for now)
#
# dayofweek -> convert to numerical (1 hot encoding for now)
#
# average -> Drop, try for regression later
#
# min -> Drop
#
# max -> Drop
#
# median -> Drop
#
# stddev -> Drop
#
# weekend -> convert to numerical (1 hot encoding for now)
#
# price_per_mile -> Target y variable

# %%
# lax_data.isnull().sum()
lax_data["price_per_mile"].plot(kind="hist")
lax_data["price_per_mile"].describe()
# Out:
# count    22611.000000
# mean         0.403434
# std          0.531082
# min          0.033032
# 25%          0.152563
# 50%          0.231842
# 75%          0.379268
# max          4.043135
# Name: price_per_mile, dtype: float64

# %%
lax_data.columns.to_list()
# Out:
# ['TO_AIRPORT',
#  'CXR',
#  'FROM_AIRPORT',
#  'week',
#  'dayofweek',
#  'average',
#  'min',
#  'max',
#  'median',
#  'stddev',
#  'weekend',
#  'miles',
#  'price_per_mile']

# %% [markdown]
# ### Machine learning
#
# Simple Lasso linear regression for airfare data.
# Pre prcessing step include one hot encoding of 'D_AIRPORT', 'CXR' and dropping one column in each to avoid bias

# %%
# Preprocessing
airfare_data_regression = lax_data.copy()
drop_columns = ["TO_AIRPORT", "average", "min", "max", "median", "stddev"]
airfare_data_regression.drop(columns = drop_columns , axis=1, inplace = True)
one_hot_encoding_columns = ["CXR", "FROM_AIRPORT", "week", "dayofweek", "weekend"]
airfare_data_regression = pd.get_dummies(airfare_data_regression,columns=one_hot_encoding_columns, 
                                         prefix = one_hot_encoding_columns, drop_first=True)
airfare_data_regression.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22611 entries, 156132 to 178742
# Data columns (total 98 columns):
# miles               22611 non-null int64
# price_per_mile      22611 non-null float64
# CXR_B6              22611 non-null uint8
# CXR_DL              22611 non-null uint8
# CXR_HA              22611 non-null uint8
# CXR_NK              22611 non-null uint8
# CXR_UA              22611 non-null uint8
# FROM_AIRPORT_BOS    22611 non-null uint8
# FROM_AIRPORT_CUN    22611 non-null uint8
# FROM_AIRPORT_DCA    22611 non-null uint8
# FROM_AIRPORT_DEN    22611 non-null uint8
# FROM_AIRPORT_DFW    22611 non-null uint8
# FROM_AIRPORT_DTW    22611 non-null uint8
# FROM_AIRPORT_EUG    22611 non-null uint8
# FROM_AIRPORT_EWR    22611 non-null uint8
# FROM_AIRPORT_FAT    22611 non-null uint8
# FROM_AIRPORT_FLL    22611 non-null uint8
# FROM_AIRPORT_HNL    22611 non-null uint8
# FROM_AIRPORT_IAD    22611 non-null uint8
# FROM_AIRPORT_IAH    22611 non-null uint8
# FROM_AIRPORT_JFK    22611 non-null uint8
# FROM_AIRPORT_KOA    22611 non-null uint8
# FROM_AIRPORT_LAS    22611 non-null uint8
# FROM_AIRPORT_LHR    22611 non-null uint8
# FROM_AIRPORT_LIH    22611 non-null uint8
# FROM_AIRPORT_MCI    22611 non-null uint8
# FROM_AIRPORT_MCO    22611 non-null uint8
# FROM_AIRPORT_MEX    22611 non-null uint8
# FROM_AIRPORT_MSP    22611 non-null uint8
# FROM_AIRPORT_MSY    22611 non-null uint8
# FROM_AIRPORT_OAK    22611 non-null uint8
# FROM_AIRPORT_OGG    22611 non-null uint8
# FROM_AIRPORT_ORD    22611 non-null uint8
# FROM_AIRPORT_PDX    22611 non-null uint8
# FROM_AIRPORT_PHL    22611 non-null uint8
# FROM_AIRPORT_RNO    22611 non-null uint8
# FROM_AIRPORT_SAN    22611 non-null uint8
# FROM_AIRPORT_SEA    22611 non-null uint8
# FROM_AIRPORT_SFO    22611 non-null uint8
# FROM_AIRPORT_SLC    22611 non-null uint8
# week_2              22611 non-null uint8
# week_3              22611 non-null uint8
# week_4              22611 non-null uint8
# week_5              22611 non-null uint8
# week_6              22611 non-null uint8
# week_7              22611 non-null uint8
# week_8              22611 non-null uint8
# week_9              22611 non-null uint8
# week_10             22611 non-null uint8
# week_11             22611 non-null uint8
# week_12             22611 non-null uint8
# week_13             22611 non-null uint8
# week_14             22611 non-null uint8
# week_15             22611 non-null uint8
# week_16             22611 non-null uint8
# week_17             22611 non-null uint8
# week_18             22611 non-null uint8
# week_19             22611 non-null uint8
# week_20             22611 non-null uint8
# week_21             22611 non-null uint8
# week_22             22611 non-null uint8
# week_23             22611 non-null uint8
# week_24             22611 non-null uint8
# week_25             22611 non-null uint8
# week_26             22611 non-null uint8
# week_27             22611 non-null uint8
# week_28             22611 non-null uint8
# week_29             22611 non-null uint8
# week_30             22611 non-null uint8
# week_31             22611 non-null uint8
# week_32             22611 non-null uint8
# week_33             22611 non-null uint8
# week_34             22611 non-null uint8
# week_35             22611 non-null uint8
# week_36             22611 non-null uint8
# week_37             22611 non-null uint8
# week_38             22611 non-null uint8
# week_39             22611 non-null uint8
# week_40             22611 non-null uint8
# week_41             22611 non-null uint8
# week_42             22611 non-null uint8
# week_43             22611 non-null uint8
# week_44             22611 non-null uint8
# week_45             22611 non-null uint8
# week_46             22611 non-null uint8
# week_47             22611 non-null uint8
# week_48             22611 non-null uint8
# week_49             22611 non-null uint8
# week_50             22611 non-null uint8
# week_51             22611 non-null uint8
# week_52             22611 non-null uint8
# dayofweek_1         22611 non-null uint8
# dayofweek_2         22611 non-null uint8
# dayofweek_3         22611 non-null uint8
# dayofweek_4         22611 non-null uint8
# dayofweek_5         22611 non-null uint8
# dayofweek_6         22611 non-null uint8
# weekend_1           22611 non-null uint8
# dtypes: float64(1), int64(1), uint8(96)
# memory usage: 2.6 MB

# %%
# Data view
airfare_data_regression.head()
# Out:
#         miles  price_per_mile  CXR_B6  CXR_DL  CXR_HA  CXR_NK  CXR_UA  \
# 156132   2469        0.112637       0       0       0       0       0
# 156133   2469        0.188443       0       0       0       0       0
# 156134   2469        0.183961       0       0       0       0       0
# 156135   2469        0.132037       0       0       0       0       0
# 156136   2469        0.114459       0       0       0       0       0
#
#         FROM_AIRPORT_BOS  FROM_AIRPORT_CUN  FROM_AIRPORT_DCA  ...  week_50  \
# 156132                 0                 0                 0  ...        0
# 156133                 0                 0                 0  ...        0
# 156134                 0                 0                 0  ...        0
# 156135                 0                 0                 0  ...        0
# 156136                 0                 0                 0  ...        0
#
#         week_51  week_52  dayofweek_1  dayofweek_2  dayofweek_3  dayofweek_4  \
# 156132        0        0            0            0            0            0
# 156133        0        0            0            1            0            0
# 156134        0        0            0            0            1            0
# 156135        0        0            0            0            0            1
# 156136        0        0            0            0            0            0
#
#         dayofweek_5  dayofweek_6  weekend_1
# 156132            0            0          1
# 156133            0            0          0
# 156134            0            0          0
# 156135            0            0          0
# 156136            1            0          1
#
# [5 rows x 98 columns]

# %%
regression_columns = [column for column in airfare_data_regression.columns.tolist() if column!="price_per_mile"]
X = airfare_data_regression[regression_columns]
y = airfare_data_regression["price_per_mile"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
print("Train RMSE error", sqrt(mean_squared_error(y_train, reg.predict(X_train))))
print("Test RMSE error", sqrt(mean_squared_error(y_test, reg.predict(X_test))))
print("Coefficients")
for x, y in zip(X_train.columns.tolist(), reg.coef_):
    print(x,round(y,2))
# Out:
# Train RMSE error 0.1489831282479632
# Test RMSE error 0.1490152627558764
# Coefficients
# miles 19942.07
# CXR_B6 0.04
# CXR_DL 0.12
# CXR_HA 0.16
# CXR_NK -0.1
# CXR_UA 0.23
# FROM_AIRPORT_BOS -27240861.67
# FROM_AIRPORT_CUN -17509133.6
# FROM_AIRPORT_DCA -21278183.91
# FROM_AIRPORT_DEN 7538100.98
# FROM_AIRPORT_DFW 139594.57
# FROM_AIRPORT_DTW -14677360.14
# FROM_AIRPORT_EUG 9771612.4
# FROM_AIRPORT_EWR -24129899.41
# FROM_AIRPORT_FAT 20540329.39
# FROM_AIRPORT_FLL -21916330.03
# FROM_AIRPORT_HNL -26203874.26
# FROM_AIRPORT_IAD -20819516.52
# FROM_AIRPORT_IAH -2732062.78
# FROM_AIRPORT_JFK -24528740.63
# FROM_AIRPORT_KOA -25166886.85
# FROM_AIRPORT_LAS 20001892.41
# FROM_AIRPORT_LHR -83836443.34
# FROM_AIRPORT_LIH -27380456.16
# FROM_AIRPORT_MCI -2432931.81
# FROM_AIRPORT_MCO -19423571.97
# FROM_AIRPORT_MEX -6261808.34
# FROM_AIRPORT_MSP -5862967.12
# FROM_AIRPORT_MSY -8535203.9
# FROM_AIRPORT_OAK 17987743.59
# FROM_AIRPORT_OGG -24807929.63
# FROM_AIRPORT_ORD -10010916.88
# FROM_AIRPORT_PDX 8056594.63
# FROM_AIRPORT_PHL -23072969.82
# FROM_AIRPORT_RNO 16910872.0
# FROM_AIRPORT_SAN 22534536.28
# FROM_AIRPORT_SEA 5663546.76
# FROM_AIRPORT_SFO 17967801.54
# FROM_AIRPORT_SLC 12942400.87
# week_2 -0.06
# week_3 -0.14
# week_4 -0.1
# week_5 -0.13
# week_6 -0.11
# week_7 -0.12
# week_8 -0.09
# week_9 -0.12
# week_10 -0.1
# week_11 -0.08
# week_12 -0.09
# week_13 -0.1
# week_14 -0.08
# week_15 -0.07
# week_16 -0.08
# week_17 -0.09
# week_18 -0.1
# week_19 -0.1
# week_20 -0.11
# week_21 -0.05
# week_22 -0.08
# week_23 -0.1
# week_24 -0.1
# week_25 -0.09
# week_26 -0.09
# week_27 -0.07
# week_28 -0.09
# week_29 -0.1
# week_30 -0.1
# week_31 -0.1
# week_32 -0.1
# week_33 -0.1
# week_34 -0.12
# week_35 -0.12
# week_36 -0.1
# week_37 -0.12
# week_38 -0.12
# week_39 -0.14
# week_40 -0.16
# week_41 -0.14
# week_42 -0.14
# week_43 -0.16
# week_44 -0.15
# week_45 -0.14
# week_46 -0.16
# week_47 -0.16
# week_48 -0.06
# week_49 -0.12
# week_50 -0.15
# week_51 -0.1
# week_52 -0.07
# dayofweek_1 0.01
# dayofweek_2 -0.03
# dayofweek_3 -0.03
# dayofweek_4 -0.02
# dayofweek_5 -0.05
# dayofweek_6 -0.06
# weekend_1 0.06

# %%
clf = linear_model.Lasso()
clf.fit(X_train, y_train)
print("Train RMSE error", sqrt(mean_squared_error(y_train, clf.predict(X_train))))
print("Test RMSE error", sqrt(mean_squared_error(y_test, clf.predict(X_test))))
print("Coefficients")
for x, y in zip(X_train.columns.tolist(), clf.coef_):
    print(x,round(y,2))
# Out:
# Train RMSE error 0.4649371722857715
# Test RMSE error 0.4561479295588175
# Coefficients
# miles -0.0
# CXR_B6 0.0
# CXR_DL 0.0
# CXR_HA 0.0
# CXR_NK -0.0
# CXR_UA 0.0
# FROM_AIRPORT_BOS 0.0
# FROM_AIRPORT_CUN -0.0
# FROM_AIRPORT_DCA 0.0
# FROM_AIRPORT_DEN -0.0
# FROM_AIRPORT_DFW -0.0
# FROM_AIRPORT_DTW -0.0
# FROM_AIRPORT_EUG -0.0
# FROM_AIRPORT_EWR 0.0
# FROM_AIRPORT_FAT 0.0
# FROM_AIRPORT_FLL -0.0
# FROM_AIRPORT_HNL 0.0
# FROM_AIRPORT_IAD 0.0
# FROM_AIRPORT_IAH -0.0
# FROM_AIRPORT_JFK 0.0
# FROM_AIRPORT_KOA 0.0
# FROM_AIRPORT_LAS -0.0
# FROM_AIRPORT_LHR 0.0
# FROM_AIRPORT_LIH 0.0
# FROM_AIRPORT_MCI -0.0
# FROM_AIRPORT_MCO -0.0
# FROM_AIRPORT_MEX 0.0
# FROM_AIRPORT_MSP -0.0
# FROM_AIRPORT_MSY -0.0
# FROM_AIRPORT_OAK -0.0
# FROM_AIRPORT_OGG 0.0
# FROM_AIRPORT_ORD -0.0
# FROM_AIRPORT_PDX -0.0
# FROM_AIRPORT_PHL -0.0
# FROM_AIRPORT_RNO -0.0
# FROM_AIRPORT_SAN 0.0
# FROM_AIRPORT_SEA -0.0
# FROM_AIRPORT_SFO -0.0
# FROM_AIRPORT_SLC -0.0
# week_2 0.0
# week_3 -0.0
# week_4 0.0
# week_5 -0.0
# week_6 -0.0
# week_7 -0.0
# week_8 0.0
# week_9 0.0
# week_10 0.0
# week_11 0.0
# week_12 0.0
# week_13 0.0
# week_14 0.0
# week_15 0.0
# week_16 0.0
# week_17 0.0
# week_18 0.0
# week_19 0.0
# week_20 -0.0
# week_21 0.0
# week_22 0.0
# week_23 0.0
# week_24 -0.0
# week_25 0.0
# week_26 0.0
# week_27 0.0
# week_28 -0.0
# week_29 0.0
# week_30 0.0
# week_31 -0.0
# week_32 0.0
# week_33 -0.0
# week_34 0.0
# week_35 -0.0
# week_36 -0.0
# week_37 -0.0
# week_38 -0.0
# week_39 -0.0
# week_40 -0.0
# week_41 -0.0
# week_42 -0.0
# week_43 -0.0
# week_44 -0.0
# week_45 -0.0
# week_46 -0.0
# week_47 -0.0
# week_48 0.0
# week_49 -0.0
# week_50 -0.0
# week_51 0.0
# week_52 0.0
# dayofweek_1 0.0
# dayofweek_2 -0.0
# dayofweek_3 -0.0
# dayofweek_4 -0.0
# dayofweek_5 -0.0
# dayofweek_6 -0.0
# weekend_1 0.0
