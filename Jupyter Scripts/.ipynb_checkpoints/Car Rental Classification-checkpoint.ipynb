# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_rental_data = pd.read_csv("../Data/car_2018 2019.csv")

# %%
car_rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27633 entries, 0 to 27632
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          27633 non-null  int64
#  1   AVG_BEFORE_DAYS     27633 non-null  float64
#  2   AVG_FARE            27633 non-null  float64
#  3   CHANGE PERCENT      27633 non-null  float64
#  4   COLLECT_DATE        27633 non-null  object
#  5   HOLIDAY             27633 non-null  int64
#  6   HOLIDAY AFTER       27633 non-null  int64
#  7   HOLIDAY BEFORE      27633 non-null  int64
#  8   LOR                 27633 non-null  int64
#  9   MAX_FARE            27633 non-null  float64
#  10  MEDIAN_FARE         27633 non-null  float64
#  11  MIN_FARE            27633 non-null  float64
#  12  OUTSIPP             27633 non-null  object
#  13  PICKUP_DATE         27633 non-null  object
#  14  TIME BEFORE RENTAL  27633 non-null  int64
#  15  WEEKEND             27633 non-null  int64
#  16  CHANGE              27633 non-null  object
# dtypes: float64(6), int64(7), object(4)
# memory usage: 3.6+ MB

# %%
# Coverting column types and dropping the right columns
car_rental_data["COLLECT_DATE"] = pd.to_datetime(car_rental_data["COLLECT_DATE"], format='%Y-%m-%d')
car_rental_data["PICKUP_DATE"] = pd.to_datetime(car_rental_data["PICKUP_DATE"], format='%Y-%m-%d')
car_rental_data.drop(columns = "Unnamed: 0", inplace = True)

# Sorting by pickup date
car_rental_data.sort_values(by = "PICKUP_DATE", inplace=True)

# %%
car_rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27633 entries, 0 to 10567
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AVG_BEFORE_DAYS     27633 non-null  float64
#  1   AVG_FARE            27633 non-null  float64
#  2   CHANGE PERCENT      27633 non-null  float64
#  3   COLLECT_DATE        27633 non-null  datetime64[ns]
#  4   HOLIDAY             27633 non-null  int64
#  5   HOLIDAY AFTER       27633 non-null  int64
#  6   HOLIDAY BEFORE      27633 non-null  int64
#  7   LOR                 27633 non-null  int64
#  8   MAX_FARE            27633 non-null  float64
#  9   MEDIAN_FARE         27633 non-null  float64
#  10  MIN_FARE            27633 non-null  float64
#  11  OUTSIPP             27633 non-null  object
#  12  PICKUP_DATE         27633 non-null  datetime64[ns]
#  13  TIME BEFORE RENTAL  27633 non-null  int64
#  14  WEEKEND             27633 non-null  int64
#  15  CHANGE              27633 non-null  object
# dtypes: datetime64[ns](2), float64(6), int64(6), object(2)
# memory usage: 3.6+ MB

# %%
car_rental_data.head()
# Out:
#        AVG_BEFORE_DAYS  AVG_FARE  CHANGE PERCENT COLLECT_DATE  HOLIDAY  \
# 0               43.655     41.51       -0.046834   2018-01-01        0
# 21978           33.960     33.71       -0.007308   2018-01-01        0
# 22019           33.630     33.45       -0.005324   2018-01-01        0
# 7748            91.080     85.87       -0.054107   2018-01-01        0
# 22060           38.385     38.31       -0.001950   2018-01-01        0
#
#        HOLIDAY AFTER  HOLIDAY BEFORE  LOR  MAX_FARE  MEDIAN_FARE   MIN_FARE  \
# 0                  0               0    7  107.6100    26.603125  18.355556
# 21978              0               0    5   61.2550    31.960750  19.011250
# 22019              0               0    5   61.2150    31.902875  18.973750
# 7748               0               0    7  196.4925    70.552083  37.237778
# 22060              0               0    5   63.9250    39.107750  21.138750
#
#       OUTSIPP PICKUP_DATE  TIME BEFORE RENTAL  WEEKEND     CHANGE
# 0        CCAR  2018-01-31                  30        0   Decrease
# 21978    CDAR  2018-01-31                  30        0   Decrease
# 22019    EDAR  2018-01-31                  30        0   Decrease
# 7748     LCAR  2018-01-31                  30        0   Decrease
# 22060    FDAR  2018-01-31                  30        0  No change

# %%
car_rental_data.isnull().sum()
# Out:
# AVG_BEFORE_DAYS       0
# AVG_FARE              0
# CHANGE PERCENT        0
# COLLECT_DATE          0
# HOLIDAY               0
# HOLIDAY AFTER         0
# HOLIDAY BEFORE        0
# LOR                   0
# MAX_FARE              0
# MEDIAN_FARE           0
# MIN_FARE              0
# OUTSIPP               0
# PICKUP_DATE           0
# TIME BEFORE RENTAL    0
# WEEKEND               0
# CHANGE                0
# dtype: int64

# %%
car_rental_data.dropna(inplace=True)

# %%
print("Min: " , min(car_rental_data["PICKUP_DATE"]), "\nMax: ", max(car_rental_data["PICKUP_DATE"]))
# Out:
# Min:  2018-01-31 00:00:00
# Max:  2020-01-29 00:00:00

# %%
# Checking for correlations
f = plt.figure(figsize=(30, 15))
plt.matshow(car_rental_data.corr(), fignum=f.number)
plt.xticks(range(car_rental_data.shape[1]), car_rental_data.columns, fontsize=14, rotation=45)
plt.yticks(range(car_rental_data.shape[1]), car_rental_data.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
corr = car_rental_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /Users/raghavsood/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /Users/raghavsood/anaconda3/lib/python3.7/site-packages/pandas/io/formats/style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# /Users/raghavsood/anaconda3/lib/python3.7/site-packages/pandas/io/formats/style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_51b7be80_834d_11ea_99ac_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row0_col1 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row0_col2 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row0_col3 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row0_col4 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row0_col5 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row0_col6 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row0_col7 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row0_col8 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row0_col9 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row0_col11 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col0 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col2 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col3 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col4 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col5 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col7 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col8 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col9 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row1_col11 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col0 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col1 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col3 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col4 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col5 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col6 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col7 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col8 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col9 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row2_col11 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col0 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col1 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col2 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col4 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col5 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col6 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col7 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col8 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col9 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row3_col11 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col0 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col1 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col2 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col3 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col6 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col7 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col8 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col9 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_51b7be80_834d_11ea_99ac_acde48001122row4_col11 {
#             background-color:  #3b4cc0;
#             color:  #f

# %% [markdown]
# # Extracting, converting the features

# %%
# Extracting year, month and date from pickup date
car_rental_data["PICKUP_DATE_YEAR"] = pd.DatetimeIndex(car_rental_data["PICKUP_DATE"]).year
car_rental_data["PICKUP_DATE_MONTH"] = pd.DatetimeIndex(car_rental_data["PICKUP_DATE"]).month
car_rental_data["PICKUP_DATE_DATE"] = pd.DatetimeIndex(car_rental_data["PICKUP_DATE"]).day

# %%
# converting car_type to one-hot encoded format
car_rental_data = pd.get_dummies(car_rental_data, columns = ["OUTSIPP"] , prefix = "OUTSIPP", drop_first=True)

# %%
car_rental_data.head(1)
# Out:
#    AVG_BEFORE_DAYS  AVG_FARE  CHANGE PERCENT COLLECT_DATE  HOLIDAY  \
# 0           43.655     41.51       -0.046834   2018-01-01        0
#
#    HOLIDAY AFTER  HOLIDAY BEFORE  LOR  MAX_FARE  MEDIAN_FARE  ...  \
# 0              0               0    7    107.61    26.603125  ...
#
#    OUTSIPP_SYMR OUTSIPP_UFAR  OUTSIPP_UXAR  OUTSIPP_WCAE OUTSIPP_WCAR  \
# 0             0            0             0             0            0
#
#    OUTSIPP_WFAR  OUTSIPP_WXAR  OUTSIPP_WZAR  OUTSIPP_XBAR  OUTSIPP_XXAR
# 0             0             0             0             0             0
#
# [1 rows x 76 columns]

# %%
car_rental_data.columns
# Out:
# Index(['AVG_BEFORE_DAYS', 'AVG_FARE', 'CHANGE PERCENT', 'COLLECT_DATE',
#        'HOLIDAY', 'HOLIDAY AFTER', 'HOLIDAY BEFORE', 'LOR', 'MAX_FARE',
#        'MEDIAN_FARE', 'MIN_FARE', 'PICKUP_DATE', 'TIME BEFORE RENTAL',
#        'WEEKEND', 'CHANGE', 'PICKUP_DATE_YEAR', 'PICKUP_DATE_MONTH',
#        'PICKUP_DATE_DATE', 'OUTSIPP_CDAR', 'OUTSIPP_CFAR', 'OUTSIPP_CTAR',
#        'OUTSIPP_ECAR', 'OUTSIPP_EDAR', 'OUTSIPP_EXAR', 'OUTSIPP_EYMR',
#        'OUTSIPP_FCAR', 'OUTSIPP_FDAR', 'OUTSIPP_FFAR', 'OUTSIPP_FJAR',
#        'OUTSIPP_FPAR', 'OUTSIPP_FRAR', 'OUTSIPP_FVAR', 'OUTSIPP_FYMR',
#        'OUTSIPP_GXAR', 'OUTSIPP_GYMR', 'OUTSIPP_ICAH', 'OUTSIPP_ICAR',
#        'OUTSIPP_IDAR', 'OUTSIPP_IFAR', 'OUTSIPP_IJAR', 'OUTSIPP_IPAR',
#        'OUTSIPP_ITAR', 'OUTSIPP_LCAR', 'OUTSIPP_LDAR', 'OUTSIPP_LFAR',
#        'OUTSIPP_LSAR', 'OUTSIPP_LTAR', 'OUTSIPP_LYMR', 'OUTSIPP_MVAR',
#        'OUTSIPP_PCAR', 'OUTSIPP_PFAR', 'OUTSIPP_PGAR', 'OUTSIPP_PPAR',
#        'OUTSIPP_PVAR', 'OUTSIPP_PXAR', 'OUTSIPP_PYMR', 'OUTSIPP_RFAR',
#        'OUTSIPP_RSAR', 'OUTSIPP_RXAR', 'OUTSIPP_SCAR', 'OUTSIPP_SDAR',
#        'OUTSIPP_SFAR', 'OUTSIPP_SPAR', 'OUTSIPP_SSAR', 'OUTSIPP_STAR',
#        'OUTSIPP_SVAR', 'OUTSIPP_SYMR', 'OUTSIPP_UFAR', 'OUTSIPP_UXAR',
#        'OUTSIPP_WCAE', 'OUTSIPP_WCAR', 'OUTSIPP_WFAR', 'OUTSIPP_WXAR',
#        'OUTSIPP_WZAR', 'OUTSIPP_XBAR', 'OUTSIPP_XXAR'],
#       dtype='object')

# %%
# Filtering features and creating a copy
classification_drop_features = ["AVG_FARE","COLLECT_DATE","LOR", 'MAX_FARE', 'MEDIAN_FARE',
       'MIN_FARE', 'PICKUP_DATE', 'TIME BEFORE RENTAL', "CHANGE PERCENT"]
classification_data = car_rental_data.copy()
classification_data.drop(columns = classification_drop_features, inplace=True)

# %%
classification_data.head()
# Out:
#        AVG_BEFORE_DAYS  HOLIDAY  HOLIDAY AFTER  HOLIDAY BEFORE  WEEKEND  \
# 0               43.655        0              0               0        0
# 21978           33.960        0              0               0        0
# 22019           33.630        0              0               0        0
# 7748            91.080        0              0               0        0
# 22060           38.385        0              0               0        0
#
#           CHANGE  PICKUP_DATE_YEAR  PICKUP_DATE_MONTH  PICKUP_DATE_DATE  \
# 0       Decrease              2018                  1                31
# 21978   Decrease              2018                  1                31
# 22019   Decrease              2018                  1                31
# 7748    Decrease              2018                  1                31
# 22060  No change              2018                  1                31
#
#        OUTSIPP_CDAR  ...  OUTSIPP_SYMR  OUTSIPP_UFAR  OUTSIPP_UXAR  \
# 0                 0  ...             0             0             0
# 21978             1  ...             0             0             0
# 22019             0  ...             0             0             0
# 7748              0  ...             0             0             0
# 22060             0  ...             0             0             0
#
#        OUTSIPP_WCAE  OUTSIPP_WCAR  OUTSIPP_WFAR  OUTSIPP_WXAR  OUTSIPP_WZAR  \
# 0                 0             0             0             0             0
# 21978             0             0             0             0             0
# 22019             0             0             0             0             0
# 7748              0             0             0             0             0
# 22060             0             0             0             0             0
#
#        OUTSIPP_XBAR  OUTSIPP_XXAR
# 0                 0             0
# 21978             0             0
# 22019             0             0
# 7748              0             0
# 22060             0             0
#
# [5 rows x 67 columns]

# %% [markdown]
# ## Scaling data

# %%
classification_data.columns
# Out:
# Index(['AVG_BEFORE_DAYS', 'HOLIDAY', 'HOLIDAY AFTER', 'HOLIDAY BEFORE',
#        'WEEKEND', 'CHANGE', 'PICKUP_DATE_YEAR', 'PICKUP_DATE_MONTH',
#        'PICKUP_DATE_DATE', 'OUTSIPP_CDAR', 'OUTSIPP_CFAR', 'OUTSIPP_CTAR',
#        'OUTSIPP_ECAR', 'OUTSIPP_EDAR', 'OUTSIPP_EXAR', 'OUTSIPP_EYMR',
#        'OUTSIPP_FCAR', 'OUTSIPP_FDAR', 'OUTSIPP_FFAR', 'OUTSIPP_FJAR',
#        'OUTSIPP_FPAR', 'OUTSIPP_FRAR', 'OUTSIPP_FVAR', 'OUTSIPP_FYMR',
#        'OUTSIPP_GXAR', 'OUTSIPP_GYMR', 'OUTSIPP_ICAH', 'OUTSIPP_ICAR',
#        'OUTSIPP_IDAR', 'OUTSIPP_IFAR', 'OUTSIPP_IJAR', 'OUTSIPP_IPAR',
#        'OUTSIPP_ITAR', 'OUTSIPP_LCAR', 'OUTSIPP_LDAR', 'OUTSIPP_LFAR',
#        'OUTSIPP_LSAR', 'OUTSIPP_LTAR', 'OUTSIPP_LYMR', 'OUTSIPP_MVAR',
#        'OUTSIPP_PCAR', 'OUTSIPP_PFAR', 'OUTSIPP_PGAR', 'OUTSIPP_PPAR',
#        'OUTSIPP_PVAR', 'OUTSIPP_PXAR', 'OUTSIPP_PYMR', 'OUTSIPP_RFAR',
#        'OUTSIPP_RSAR', 'OUTSIPP_RXAR', 'OUTSIPP_SCAR', 'OUTSIPP_SDAR',
#        'OUTSIPP_SFAR', 'OUTSIPP_SPAR', 'OUTSIPP_SSAR', 'OUTSIPP_STAR',
#        'OUTSIPP_SVAR', 'OUTSIPP_SYMR', 'OUTSIPP_UFAR', 'OUTSIPP_UXAR',
#        'OUTSIPP_WCAE', 'OUTSIPP_WCAR', 'OUTSIPP_WFAR', 'OUTSIPP_WXAR',
#        'OUTSIPP_WZAR', 'OUTSIPP_XBAR', 'OUTSIPP_XXAR'],
#       dtype='object')

# %%
# classification_data[["AVG_BEFORE_DAYS", "CHANGE PERCENT"]].head(20)
classification_data[["AVG_BEFORE_DAYS"]].head(20)
# Out:
#        AVG_BEFORE_DAYS
# 0               43.655
# 21978           33.960
# 22019           33.630
# 7748            91.080
# 22060           38.385
# 22101           36.450
# 22142           98.760
# 22183           38.665
# 7043            66.900
# 6338            45.075
# 5635           121.120
# 4935            79.345
# 4230           104.075
# 3525            98.500
# 2820            46.135
# 2115            46.460
# 8453           133.460
# 1410            43.570
# 21274           23.060
# 9863            74.560

# %%
# Scaling AVG_BEFORE_DAYS and CHANGE PERCENT
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# classification_data[["AVG_BEFORE_DAYS", "CHANGE PERCENT"]] = scaler.fit_transform(classification_data[["AVG_BEFORE_DAYS", "CHANGE PERCENT"]])
classification_data[["AVG_BEFORE_DAYS"]] = scaler.fit_transform(classification_data[["AVG_BEFORE_DAYS"]])

# %%
# classification_data[["AVG_BEFORE_DAYS", "CHANGE PERCENT"]].head(20)
classification_data[["AVG_BEFORE_DAYS"]].head(20)
# Out:
#        AVG_BEFORE_DAYS
# 0            -1.182342
# 21978        -1.410733
# 22019        -1.418507
# 7748         -0.065126
# 22060        -1.306491
# 22101        -1.352075
# 22142         0.115796
# 22183        -1.299895
# 7043         -0.634747
# 6338         -1.148891
# 5635          0.642542
# 4935         -0.341574
# 4230          0.241004
# 3525          0.109671
# 2820         -1.123920
# 2115         -1.116264
# 8453          0.933242
# 1410         -1.184345
# 21274        -1.667510
# 9863         -0.454297

# %% [markdown]
# # Machine Learning - Random Forest

# %%
# Extracting columns
classification_columns = [x for x in classification_data.columns.to_list() if x != "CHANGE"]
X = classification_data[classification_columns]
y = classification_data["CHANGE"]

# %%
X_train = X[:int(X.shape[0]*0.7)]
X_test = X[int(X.shape[0]*0.7):]
y_train = y[:int(X.shape[0]*0.7)]
y_test = y[int(X.shape[0]*0.7):]

# %%
# Checking correct sort order for train test splits
print("Min train date:", min(X_train["PICKUP_DATE_YEAR"]*100 + X_train["PICKUP_DATE_MONTH"]))
print("Max train date:", max(X_train["PICKUP_DATE_YEAR"]*100 + X_train["PICKUP_DATE_MONTH"]))
# Out:
# Min train date: 201801
# Max train date: 201907

# %%
# Importing
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, balanced_accuracy_score, make_scorer

# %%
# Default model
default = RandomForestClassifier(random_state=1)
default.fit(X_train, y_train)
default_pred = default.predict(X_test)
print("Accuracy for default Random Forest on CV data: ",accuracy_score(y_test,default_pred))
print()
print("Balanced Accuracy for default Random Forest on CV data: ",balanced_accuracy_score(y_test,default_pred))
print()
for x, y in zip(X_train.columns.tolist(), default.feature_importances_):
    print(x,round(y,2))
print()
print("AUC", roc_auc_score(y_test, default.predict_proba(X_test)[:,1]))
# Out:
# Accuracy for default Random Forest on CV data:  0.3831121833534379
#
# Balanced Accuracy for default Random Forest on CV data:  0.40877368466863434
#
# AVG_BEFORE_DAYS 0.27
# HOLIDAY 0.01
# HOLIDAY AFTER 0.01
# HOLIDAY BEFORE 0.01
# WEEKEND 0.02
# PICKUP_DATE_YEAR 0.02
# PICKUP_DATE_MONTH 0.21
# PICKUP_DATE_DATE 0.21
# OUTSIPP_CDAR 0.0
# OUTSIPP_CFAR 0.01
# OUTSIPP_CTAR 0.0
# OUTSIPP_ECAR 0.0
# OUTSIPP_EDAR 0.0
# OUTSIPP_EXAR 0.0
# OUTSIPP_EYMR 0.0
# OUTSIPP_FCAR 0.0
# OUTSIPP_FDAR 0.0
# OUTSIPP_FFAR 0.01
# OUTSIPP_FJAR 0.0
# OUTSIPP_FPAR 0.01
# OUTSIPP_FRAR 0.01
# OUTSIPP_FVAR 0.0
# OUTSIPP_FYMR 0.0
# OUTSIPP_GXAR 0.01
# OUTSIPP_GYMR 0.0
# OUTSIPP_ICAH 0.0
# OUTSIPP_ICAR 0.0
# OUTSIPP_IDAR 0.0
# OUTSIPP_IFAR 0.0
# OUTSIPP_IJAR 0.01
# OUTSIPP_IPAR 0.0
# OUTSIPP_ITAR 0.0
# OUTSIPP_LCAR 0.01
# OUTSIPP_LDAR 0.0
# OUTSIPP_LFAR 0.01
# OUTSIPP_LSAR 0.01
# OUTSIPP_LTAR 0.01
# OUTSIPP_LYMR 0.0
# OUTSIPP_MVAR 0.01
# OUTSIPP_PCAR 0.0
# OUTSIPP_PFAR 0.01
# OUTSIPP_PGAR 0.01
# OUTSIPP_PPAR 0.01
# OUTSIPP_PVAR 0.0
# OUTSIPP_PXAR 0.01
# OUTSIPP_PYMR 0.0
# OUTSIPP_RFAR 0.01
# OUTSIPP_RSAR 0.01
# OUTSIPP_RXAR 0.01
# OUTSIPP_SCAR 0.0
# OUTSIPP_SDAR 0.0
# OUTSIPP_SFAR 0.0
# OUTSIPP_SPAR 0.01
# OUTSIPP_SSAR 0.01
# OUTSIPP_STAR 0.01
# OUTSIPP_SVAR 0.01
# OUTSIPP_SYMR 0.0
# OUTSIPP_UFAR 0.01
# OUTSIPP_UXAR 0.01
# OUTSIPP_WCAE 0.0
# OUTSIPP_WCAR 0.0
# OUTSIPP_WFAR 0.01
# OUTSIPP_WXAR 0.0
# OUTSIPP_WZAR 0.0
# OUTSIPP_XBAR 0.0
# OUTSIPP_XXAR 0.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-f02cf1571e40> in <module>
#      10     print(x,round(y,2))
#      11 print()
# ---> 12 print("AUC", roc_auc_score(y_test, default.predict_proba(X_test)[:,1]))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     379                              "instead".format(max_fpr))
#     380         if multi_class == 'raise':
# --> 381             raise ValueError("multi_class must be in ('ovo', 'ovr')")
#     382         return _multiclass_roc_auc_score(y_true, y_score, labels,
#     383                                          multi_class, average, sample_weight)
#
# ValueError: multi_class must be in ('ovo', 'ovr')

# %%
# %timeit
rfc = RandomForestClassifier(random_state=1)
# Setting grid parameters
n_estimators = [100, 200, 300, 500, 800]
max_depth = [None, 4, 5, 6, 7, 8, 9, 10]
max_features = ['auto', 'sqrt', 'log2']
# min_samples_split = [2, 5, 10, 15, 100]
# min_samples_leaf = [1, 2, 5, 10]
criterion = ['gini', 'entropy']


parameters = dict(n_estimators = n_estimators, max_depth = max_depth,
                  criterion = criterion, max_features = max_features)

gridF = GridSearchCV(estimator = rfc, param_grid = parameters, cv = 5, verbose = 1,
                      n_jobs = -1)
gridF.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 1200 out of 1200 | elapsed: 14.1min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 4, 5, 6, 7, 8, 9, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300, 500, 800]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=1)

# %%
# Best parameters
gridF.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 4,
#  'max_features': 'log2',
#  'n_estimators': 500}

# %%
# Reinitializing the best model
best_model = RandomForestClassifier(random_state=1, criterion="entropy", max_depth=4, max_features="log2", 
                                   n_estimators=500)
best_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=4, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)

# %%
pred = best_model.predict(X_test)
print("Accuracy for best Random Forest on CV data: ",accuracy_score(y_test,pred))
# Out:
# Accuracy for best Random Forest on CV data:  0.4384800965018094

# %%
print("Balanced Accuracy for default Random Forest on CV data: ",balanced_accuracy_score(y_test,pred))
# Out:
# Balanced Accuracy for default Random Forest on CV data:  0.3545006982085526

# %%
print("AUC", roc_auc_score(y_test, best_model.predict_proba(X_test)[:,1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-cae18ecefda4> in <module>
# ----> 1 print("AUC", roc_auc_score(y_test, best_model.predict_proba(X_test)[:,1]))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     379                              "instead".format(max_fpr))
#     380         if multi_class == 'raise':
# --> 381             raise ValueError("multi_class must be in ('ovo', 'ovr')")
#     382         return _multiclass_roc_auc_score(y_true, y_score, labels,
#     383                                          multi_class, average, sample_weight)
#
# ValueError: multi_class must be in ('ovo', 'ovr')

# %%
for x, y in zip(X_train.columns.tolist(), best_model.feature_importances_):
    print(x,round(y,2))
# Out:
# AVG_BEFORE_DAYS 0.14
# HOLIDAY 0.01
# HOLIDAY AFTER 0.01
# HOLIDAY BEFORE 0.01
# WEEKEND 0.0
# PICKUP_DATE_YEAR 0.05
# PICKUP_DATE_MONTH 0.23
# PICKUP_DATE_DATE 0.08
# OUTSIPP_CDAR 0.0
# OUTSIPP_CFAR 0.0
# OUTSIPP_CTAR 0.0
# OUTSIPP_ECAR 0.0
# OUTSIPP_EDAR 0.0
# OUTSIPP_EXAR 0.0
# OUTSIPP_EYMR 0.0
# OUTSIPP_FCAR 0.0
# OUTSIPP_FDAR 0.01
# OUTSIPP_FFAR 0.01
# OUTSIPP_FJAR 0.0
# OUTSIPP_FPAR 0.0
# OUTSIPP_FRAR 0.0
# OUTSIPP_FVAR 0.01
# OUTSIPP_FYMR 0.0
# OUTSIPP_GXAR 0.0
# OUTSIPP_GYMR 0.0
# OUTSIPP_ICAH 0.0
# OUTSIPP_ICAR 0.0
# OUTSIPP_IDAR 0.0
# OUTSIPP_IFAR 0.0
# OUTSIPP_IJAR 0.0
# OUTSIPP_IPAR 0.0
# OUTSIPP_ITAR 0.0
# OUTSIPP_LCAR 0.0
# OUTSIPP_LDAR 0.0
# OUTSIPP_LFAR 0.0
# OUTSIPP_LSAR 0.0
# OUTSIPP_LTAR 0.11
# OUTSIPP_LYMR 0.0
# OUTSIPP_MVAR 0.01
# OUTSIPP_PCAR 0.0
# OUTSIPP_PFAR 0.0
# OUTSIPP_PGAR 0.0
# OUTSIPP_PPAR 0.0
# OUTSIPP_PVAR 0.01
# OUTSIPP_PXAR 0.0
# OUTSIPP_PYMR 0.0
# OUTSIPP_RFAR 0.0
# OUTSIPP_RSAR 0.14
# OUTSIPP_RXAR 0.04
# OUTSIPP_SCAR 0.0
# OUTSIPP_SDAR 0.0
# OUTSIPP_SFAR 0.0
# OUTSIPP_SPAR 0.0
# OUTSIPP_SSAR 0.01
# OUTSIPP_STAR 0.01
# OUTSIPP_SVAR 0.0
# OUTSIPP_SYMR 0.0
# OUTSIPP_UFAR 0.0
# OUTSIPP_UXAR 0.0
# OUTSIPP_WCAE 0.01
# OUTSIPP_WCAR 0.02
# OUTSIPP_WFAR 0.02
# OUTSIPP_WXAR 0.0
# OUTSIPP_WZAR 0.0
# OUTSIPP_XBAR 0.0
# OUTSIPP_XXAR 0.03
