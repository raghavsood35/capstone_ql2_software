# %%
import pandas as pd
from datetime import date
import numpy as np

# %%
# if ModuleNotFoundError: No module named 'holidays'
# uncomment next line and run it once

# ! pip install holidays

# %%
import holidays

# %%
from datetime import timedelta

# %%
file_name = "result_2019.csv"  # sample dataset

# %%
data = pd.read_csv(file_name)

# %%
data["PICKUP_DATE"] = data["PICKUP_DATE"] .astype('datetime64[ns]')
data["COLLECT_DATE"] = data["COLLECT_DATE"] .astype('datetime64[ns]')

# %%
data
# Out:
#         COLLECT_DATE PICKUP_DATE            CAR_TYPE  LOR  AVG_FARE  \
# 0         2018-02-15  2019-01-04             Compact    2     80.81
# 1         2018-02-15  2019-01-05             Compact    2     80.81
# 2         2018-02-15  2019-01-04         Compact SUV    2    173.04
# 3         2018-02-15  2019-01-05         Compact SUV    2    173.04
# 4         2018-02-15  2019-01-04             Economy    2     78.28
# ...              ...         ...                 ...  ...       ...
# 2245818   2020-01-01  2020-01-25  Standard SportsCar   30     46.06
# 2245819   2020-01-01  2020-01-26  Standard SportsCar   30     46.06
# 2245820   2020-01-01  2020-01-27  Standard SportsCar   30     46.06
# 2245821   2020-01-01  2020-01-28  Standard SportsCar   30     46.06
# 2245822   2020-01-01  2020-01-29  Standard SportsCar   30     46.06
#
#            MIN_FARE    MAX_FARE  MEDIAN_FARE
# 0         33.800000  127.235000    78.600000
# 1         33.800000  127.235000    78.600000
# 2        140.195000  196.140000   182.795000
# 3        140.195000  196.140000   182.795000
# 4         33.735000  124.625000    75.465000
# ...             ...         ...          ...
# 2245818   41.304333   49.853333    47.019667
# 2245819   41.304333   49.853333    47.019667
# 2245820   41.304333   49.853333    47.019667
# 2245821   41.304333   49.853333    47.019667
# 2245822   41.304333   49.853333    47.019667
#
# [2245823 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2245823 entries, 0 to 2245822
# Data columns (total 8 columns):
# COLLECT_DATE    datetime64[ns]
# PICKUP_DATE     datetime64[ns]
# CAR_TYPE        object
# LOR             int64
# AVG_FARE        float64
# MIN_FARE        float64
# MAX_FARE        float64
# MEDIAN_FARE     float64
# dtypes: datetime64[ns](2), float64(4), int64(1), object(1)
# memory usage: 137.1+ MB

# %%
us_holidays = holidays.CountryHoliday('US', prov=None, state='CA')

# %%
# for ptr in holidays.US(years = 2020, state='CA').items(): 
#     print(ptr)

# %%
data["HOLIDAY"] = [int(x in us_holidays) for x in data["PICKUP_DATE"]]

# %%
# whether pick up date is one day before/after the public holiday
# one day before
# one day after
data["HOLIDAY BEFORE"] = [int(x + timedelta(days=1) in us_holidays) for x in data["PICKUP_DATE"]]
data["HOLIDAY AFTER"] = [int(x - timedelta(days=1) in us_holidays) for x in data["PICKUP_DATE"]]

# %%
data["TIME BEFORE RENTAL"] = ((data["PICKUP_DATE"] - data["COLLECT_DATE"])/ np.timedelta64(1, 'D')).astype(int)

# %%
data
# Out:
#         COLLECT_DATE PICKUP_DATE            CAR_TYPE  LOR  AVG_FARE  \
# 0         2018-02-15  2019-01-04             Compact    2     80.81
# 1         2018-02-15  2019-01-05             Compact    2     80.81
# 2         2018-02-15  2019-01-04         Compact SUV    2    173.04
# 3         2018-02-15  2019-01-05         Compact SUV    2    173.04
# 4         2018-02-15  2019-01-04             Economy    2     78.28
# ...              ...         ...                 ...  ...       ...
# 2245818   2020-01-01  2020-01-25  Standard SportsCar   30     46.06
# 2245819   2020-01-01  2020-01-26  Standard SportsCar   30     46.06
# 2245820   2020-01-01  2020-01-27  Standard SportsCar   30     46.06
# 2245821   2020-01-01  2020-01-28  Standard SportsCar   30     46.06
# 2245822   2020-01-01  2020-01-29  Standard SportsCar   30     46.06
#
#            MIN_FARE    MAX_FARE  MEDIAN_FARE  HOLIDAY  HOLIDAY BEFORE  \
# 0         33.800000  127.235000    78.600000        0               0
# 1         33.800000  127.235000    78.600000        0               0
# 2        140.195000  196.140000   182.795000        0               0
# 3        140.195000  196.140000   182.795000        0               0
# 4         33.735000  124.625000    75.465000        0               0
# ...             ...         ...          ...      ...             ...
# 2245818   41.304333   49.853333    47.019667        0               0
# 2245819   41.304333   49.853333    47.019667        0               0
# 2245820   41.304333   49.853333    47.019667        0               0
# 2245821   41.304333   49.853333    47.019667        0               0
# 2245822   41.304333   49.853333    47.019667        0               0
#
#          HOLIDAY AFTER  TIME BEFORE RENTAL
# 0                    0                 323
# 1                    0                 324
# 2                    0                 323
# 3                    0                 324
# 4                    0                 323
# ...                ...                 ...
# 2245818              0                  24
# 2245819              0                  25
# 2245820              0                  26
# 2245821              0                  27
# 2245822              0                  28
#
# [2245823 rows x 12 columns]

# %%
# average part starts:

# %%
new_data2 = data[data["TIME BEFORE RENTAL"] == 30]

# %%
new_data2
# Out:
#         COLLECT_DATE PICKUP_DATE                     CAR_TYPE  LOR  AVG_FARE  \
# 466427    2018-12-02  2019-01-01                      Compact    5     68.16
# 466428    2018-12-02  2019-01-01          Compact Convertible    5    187.71
# 466429    2018-12-02  2019-01-01                  Compact SUV    5     79.47
# 466430    2018-12-02  2019-01-01                      Economy    5     68.12
# 466431    2018-12-02  2019-01-01              Economy Special    5     70.57
# ...              ...         ...                          ...  ...       ...
# 2243952   2019-12-30  2020-01-29           Standard Elite SUV   30     55.81
# 2243953   2019-12-30  2020-01-29     Standard Elite SportsCar   30     83.12
# 2243954   2019-12-30  2020-01-29  Standard Pickup Regular Cab   30     41.65
# 2243955   2019-12-30  2020-01-29                 Standard SUV   30     47.72
# 2243956   2019-12-30  2020-01-29           Standard SportsCar   30     50.54
#
#            MIN_FARE    MAX_FARE  MEDIAN_FARE  HOLIDAY  HOLIDAY BEFORE  \
# 466427    20.928333  106.420000    82.373750        1               0
# 466428   144.710000  240.646000   172.768571        1               0
# 466429    45.704444  108.004000   101.483000        1               0
# 466430    20.891667  106.372000    82.351250        1               0
# 466431    39.703750  105.894000    68.743333        1               0
# ...             ...         ...          ...      ...             ...
# 2243952   53.221000   58.402667    55.811833        0               0
# 2243953   78.154000   88.087000    83.120500        0               0
# 2243954   41.652667   41.652667    41.652667        0               0
# 2243955   41.245000   52.739000    47.623333        0               0
# 2243956   49.853333   50.887333    50.886000        0               0
#
#          HOLIDAY AFTER  TIME BEFORE RENTAL
# 466427               0                  30
# 466428               0                  30
# 466429               0                  30
# 466430               0                  30
# 466431               0                  30
# ...                ...                 ...
# 2243952              0                  30
# 2243953              0                  30
# 2243954              0                  30
# 2243955              0                  30
# 2243956              0                  30
#
# [15444 rows x 12 columns]

# %%
# avg for same car type, N days before
d_sort = new_data2.sort_values(by=['CAR_TYPE','PICKUP_DATE'])
car_type = new_data2["CAR_TYPE"].unique().tolist()

# %%
# # car type for loop %timeit whole data
# for i in range(0,1):
#     %timeit d_sub = d_sort[d_sort["CAR_TYPE"]==car_type[i]] 
#     d_sub = d_sub.reset_index(drop = True)
#     d_sub["AVG_BEFORE_DAYS"] = [d_sub["AVG_FARE"][max(0, i-15):i+1].mean() for i in range(0, len(d_sub["AVG_FARE"]))]

# %%
# d_sub = d_sort[d_sort["CAR_TYPE"]==car_type[1]] 
# d_sub = d_sub.reset_index(drop = True)
# d_sub["AVG_BEFORE_DAYS"] = [d_sub["AVG_FARE"][max(0, i-15):i+1].mean() for i in range(0, len(d_sub["AVG_FARE"]))]

# %%
for i in range(0,len(car_type)):
    d_sub = d_sort[d_sort["CAR_TYPE"]==car_type[i]] 
    d_sub = d_sub.reset_index(drop = True)
    d_sub["AVG_BEFORE_DAYS"] = [d_sub["AVG_FARE"][max(0, i-15):i+1].mean() for i in range(0, len(d_sub["AVG_FARE"]))]
    df_all = df_all.append(d_sub, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-d75a3f666e49> in <module>
#       3     d_sub = d_sub.reset_index(drop = True)
#       4     d_sub["AVG_BEFORE_DAYS"] = [d_sub["AVG_FARE"][max(0, i-15):i+1].mean() for i in range(0, len(d_sub["AVG_FARE"]))]
# ----> 5     df_all = df_all.append(d_sub, ignore_index=True)
#
# NameError: name 'df_all' is not defined

# %%
df_all

# %%
change = [(df_all["AVG_BEFORE_DAYS"][i + 1] - df_all["AVG_BEFORE_DAYS"][i])/df_all["AVG_BEFORE_DAYS"][i] for i in range(0, len(df_all["AVG_BEFORE_DAYS"])-1)] 
change.append(None)
df_all["CHANGE PERCENT"] = change

# %%
df_all["CHANGE PERCENT"].describe()

# %%
threshold = df_all["CHANGE PERCENT"].describe()["50%"]

# %%
f = lambda x : "Increase" if x > threshold  else ("Decrease" if x < -threshold else "No change")
df_all["CHANGE"] = [ f(x) for x in df_all["CHANGE PERCENT"]]

# %%
df_all

# %%
df_all.to_csv("car 2019.csv")

# %%
file = "feat_extract_result_2019.csv"  # sample dataset
d =  pd.read_csv(file)

# %%
d["CHANGE PERCENT"].describe()
# Out:
# count    15443.000000
# mean         0.001263
# std          0.076647
# min         -0.519146
# 25%         -0.007113
# 50%         -0.000684
# 75%          0.004423
# max          5.322503
# Name: CHANGE PERCENT, dtype: float64

# %%
threshold = d["CHANGE PERCENT"].describe()["50%"]

# %%
f = lambda x : "Increase" if x > threshold  else ("Decrease" if x < -threshold else "No change")
d["CHANGE"] = [ f(x) for x in d["CHANGE PERCENT"]]

# %%
d
# Out:
#        AVG_BEFORE_DAYS  AVG_FARE                        CAR_TYPE COLLECT_DATE  \
# 0               68.160     68.16                         Compact   2018-12-02
# 1               68.075     67.99                         Compact   2018-12-03
# 2               67.560     66.53                         Compact   2018-12-04
# 3               66.800     64.52                         Compact   2018-12-05
# 4               65.436     59.98                         Compact   2018-12-06
# ...                ...       ...                             ...          ...
# 15439          388.830    388.83  Fullsize Elite 2 Wheel Vehicle   2019-11-28
# 15440          388.830    388.83  Fullsize Elite 2 Wheel Vehicle   2019-11-29
# 15441          388.830    388.83  Fullsize Elite 2 Wheel Vehicle   2019-11-30
# 15442          388.830    388.83  Fullsize Elite 2 Wheel Vehicle   2019-12-01
# 15443          388.830    388.83  Fullsize Elite 2 Wheel Vehicle   2019-12-02
#
#        HOLIDAY  HOLIDAY AFTER  HOLIDAY BEFORE  LOR  MAX_FARE  MEDIAN_FARE  \
# 0            1              0               0    5   106.420    82.373750
# 1            0              1               0    6   106.420    82.638333
# 2            0              0               0    6   106.420    81.364583
# 3            0              0               0    6   124.090    74.810313
# 4            0              0               0    6   111.165    63.865714
# ...        ...            ...             ...  ...       ...          ...
# 15439        0              0               0    5   388.834   388.834000
# 15440        0              0               0    5   388.834   388.834000
# 15441        0              0               0    5   388.834   388.834000
# 15442        0              0               1    5   388.834   388.834000
# 15443        1              0               0    5   388.834   388.834000
#
#          MIN_FARE PICKUP_DATE  TIME BEFORE RENTAL  CHANGE PERCENT     CHANGE
# 0       20.928333  2019-01-01                  30       -0.001247   Decrease
# 1       20.928333  2019-01-02                  30       -0.007565   Decrease
# 2       20.476667  2019-01-03                  30       -0.011249   Decrease
# 3       18.157143  2019-01-04                  30       -0.020419   Decrease
# 4       19.818889  2019-01-05                  30       -0.017310   Decrease
# ...           ...         ...                 ...             ...        ...
# 15439  388.834000  2019-12-28                  30        0.000000   Increase
# 15440  388.834000  2019-12-29                  30        0.000000   Increase
# 15441  388.834000  2019-12-30                  30        0.000000   Increase
# 15442  388.834000  2019-12-31                  30        0.000000   Increase
# 15443  388.834000  2020-01-01                  30             NaN  No change
#
# [15444 rows x 15 columns]

# %%
d.to_csv("car_feat_2019.csv")
