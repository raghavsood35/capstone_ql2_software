# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure

# %%
car_rental_data = pd.read_csv("../Data/new_carrental_features.csv")

# %%
car_rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27633 entries, 0 to 27632
# Data columns (total 17 columns):
# Unnamed: 0            27633 non-null int64
# AVG_BEFORE_DAYS       27633 non-null float64
# AVG_FARE              27633 non-null float64
# CHANGE PERCENT        27633 non-null float64
# COLLECT_DATE          27633 non-null object
# HOLIDAY               27633 non-null int64
# HOLIDAY AFTER         27633 non-null int64
# HOLIDAY BEFORE        27633 non-null int64
# LOR                   27633 non-null int64
# MAX_FARE              27633 non-null float64
# MEDIAN_FARE           27633 non-null float64
# MIN_FARE              27633 non-null float64
# OUTSIPP               27633 non-null object
# PICKUP_DATE           27633 non-null object
# TIME BEFORE RENTAL    27633 non-null int64
# WEEKEND               27633 non-null int64
# CHANGE                27633 non-null object
# dtypes: float64(6), int64(7), object(4)
# memory usage: 3.6+ MB

# %%
# Coverting column types and dropping the right columns
car_rental_data["COLLECT_DATE"] = pd.to_datetime(car_rental_data["COLLECT_DATE"], format='%Y-%m-%d')
car_rental_data["PICKUP_DATE"] = pd.to_datetime(car_rental_data["PICKUP_DATE"], format='%Y-%m-%d')
car_rental_data.drop(columns = "Unnamed: 0", inplace = True)

# Sorting by pickup date
car_rental_data.sort_values(by = "PICKUP_DATE", inplace=True)

# %%
car_rental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27633 entries, 0 to 10567
# Data columns (total 16 columns):
# AVG_BEFORE_DAYS       27633 non-null float64
# AVG_FARE              27633 non-null float64
# CHANGE PERCENT        27633 non-null float64
# COLLECT_DATE          27633 non-null datetime64[ns]
# HOLIDAY               27633 non-null int64
# HOLIDAY AFTER         27633 non-null int64
# HOLIDAY BEFORE        27633 non-null int64
# LOR                   27633 non-null int64
# MAX_FARE              27633 non-null float64
# MEDIAN_FARE           27633 non-null float64
# MIN_FARE              27633 non-null float64
# OUTSIPP               27633 non-null object
# PICKUP_DATE           27633 non-null datetime64[ns]
# TIME BEFORE RENTAL    27633 non-null int64
# WEEKEND               27633 non-null int64
# CHANGE                27633 non-null object
# dtypes: datetime64[ns](2), float64(6), int64(6), object(2)
# memory usage: 3.6+ MB

# %%
car_rental_data.head()
# Out:
#        AVG_BEFORE_DAYS  AVG_FARE  CHANGE PERCENT COLLECT_DATE  HOLIDAY  \
# 0               43.655     41.51       -0.046834   2018-01-01        0
# 21978           33.960     33.71       -0.007308   2018-01-01        0
# 22019           33.630     33.45       -0.005324   2018-01-01        0
# 7748            91.080     85.87       -0.054107   2018-01-01        0
# 22060           38.385     38.31       -0.001950   2018-01-01        0
#
#        HOLIDAY AFTER  HOLIDAY BEFORE  LOR  MAX_FARE  MEDIAN_FARE   MIN_FARE  \
# 0                  0               0    7  107.6100    26.603125  18.355556
# 21978              0               0    5   61.2550    31.960750  19.011250
# 22019              0               0    5   61.2150    31.902875  18.973750
# 7748               0               0    7  196.4925    70.552083  37.237778
# 22060              0               0    5   63.9250    39.107750  21.138750
#
#       OUTSIPP PICKUP_DATE  TIME BEFORE RENTAL  WEEKEND     CHANGE
# 0        CCAR  2018-01-31                  30        0   Decrease
# 21978    CDAR  2018-01-31                  30        0   Decrease
# 22019    EDAR  2018-01-31                  30        0   Decrease
# 7748     LCAR  2018-01-31                  30        0   Decrease
# 22060    FDAR  2018-01-31                  30        0  No change

# %% [markdown]
# *****
# Reduce outsipp to 5 logical categories

# %%
temp1 = car_rental_data.loc[:,["OUTSIPP" , "AVG_FARE"]].groupby("OUTSIPP")["AVG_FARE"].mean()
temp1[:5]
# Out:
# OUTSIPP
# CCAR     63.689617
# CDAR     59.771463
# CFAR     70.709957
# CTAR    122.003715
# ECAR     63.491191
# Name: AVG_FARE, dtype: float64

# %%
temp1.describe()
# Out:
# count     59.000000
# mean     108.767105
# std       80.779448
# min       49.092145
# 25%       67.115521
# 50%       85.943560
# 75%      120.135808
# max      509.005000
# Name: AVG_FARE, dtype: float64

# %%
plt.figure(figsize=(15,7))
plt.plot(temp1.sort_values())
plt.xticks(rotation = 90)
plt.show()

# %%
temp1 = temp1.drop(["GYMR" , "PYMR" , "EYMR"] , axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-ec6fc3b8ef9f> in <module>
# ----> 1 temp1 = temp1.drop(["GYMR" , "PYMR" , "EYMR"] , axis = 0)
#
# E:\Anaconda\lib\site-packages\pandas\core\series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4321             level=level,
#    4322             inplace=inplace,
# -> 4323             errors=errors,
#    4324         )
#    4325
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# E:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['GYMR' 'PYMR' 'EYMR'] not found in axis"

# %%
# premium > luxury > midrange> economy > basic

ref1 = pd.qcut(temp1 , 4 , labels = [ "basic" , "economy" , "midrange" , "luxury"])
ref1 = ref.append(pd.Series( data = ["premium","premium","premium"] , index =["GYMR" , "PYMR" , "EYMR"]))
ref1[:5]

# %% [markdown]
# *****
# Second scheme

# %%
temp2 = car_rental_data.loc[:,["OUTSIPP" , "AVG_FARE"]].groupby("OUTSIPP")["AVG_FARE"].mean()
ref = temp2.sort_values().reset_index()
ref2 = pd.Series( data = ref.index/sum(ref.index) , index=ref["OUTSIPP"])
ref2[:5]

# %%
#Choose ref1 or ref2
ref = ref2

# %%
car_rental_data["new_OUTSIPP"] = ref[car_rental_data["OUTSIPP"]].to_list()

# %%
orig_car_rental_data = car_rental_data[:]

# %%
car_rental_data = car_rental_data.drop(columns = "OUTSIPP")
car_rental_data.columns
# Out:
# Index(['AVG_BEFORE_DAYS', 'AVG_FARE', 'CHANGE PERCENT', 'COLLECT_DATE',
#        'HOLIDAY', 'HOLIDAY AFTER', 'HOLIDAY BEFORE', 'LOR', 'MAX_FARE',
#        'MEDIAN_FARE', 'MIN_FARE', 'PICKUP_DATE', 'TIME BEFORE RENTAL',
#        'WEEKEND', 'CHANGE'],
#       dtype='object')

# %%
car_rental_data.head()
# Out:
#        AVG_BEFORE_DAYS  AVG_FARE  CHANGE PERCENT COLLECT_DATE  HOLIDAY  \
# 0               43.655     41.51       -0.046834   2018-01-01        0
# 21978           33.960     33.71       -0.007308   2018-01-01        0
# 22019           33.630     33.45       -0.005324   2018-01-01        0
# 7748            91.080     85.87       -0.054107   2018-01-01        0
# 22060           38.385     38.31       -0.001950   2018-01-01        0
#
#        HOLIDAY AFTER  HOLIDAY BEFORE  LOR  MAX_FARE  MEDIAN_FARE   MIN_FARE  \
# 0                  0               0    7  107.6100    26.603125  18.355556
# 21978              0               0    5   61.2550    31.960750  19.011250
# 22019              0               0    5   61.2150    31.902875  18.973750
# 7748               0               0    7  196.4925    70.552083  37.237778
# 22060              0               0    5   63.9250    39.107750  21.138750
#
#       PICKUP_DATE  TIME BEFORE RENTAL  WEEKEND     CHANGE
# 0      2018-01-31                  30        0   Decrease
# 21978  2018-01-31                  30        0   Decrease
# 22019  2018-01-31                  30        0   Decrease
# 7748   2018-01-31                  30        0   Decrease
# 22060  2018-01-31                  30        0  No change

# %%
car_rental_data.isnull().sum()
# Out:
# AVG_BEFORE_DAYS       0
# AVG_FARE              0
# CHANGE PERCENT        0
# COLLECT_DATE          0
# HOLIDAY               0
# HOLIDAY AFTER         0
# HOLIDAY BEFORE        0
# LOR                   0
# MAX_FARE              0
# MEDIAN_FARE           0
# MIN_FARE              0
# PICKUP_DATE           0
# TIME BEFORE RENTAL    0
# WEEKEND               0
# CHANGE                0
# dtype: int64

# %%
car_rental_data.dropna(inplace=True)

# %%
print("Min: " , min(car_rental_data["PICKUP_DATE"]), "\nMax: ", max(car_rental_data["PICKUP_DATE"]))
# Out:
# Min:  2018-01-31 00:00:00
# Max:  2020-01-29 00:00:00

# %%
# Checking for correlations
f = plt.figure(figsize=(30, 15))
plt.matshow(car_rental_data.corr(), fignum=f.number)
plt.xticks(range(car_rental_data.shape[1]), car_rental_data.columns, fontsize=14, rotation=45)
plt.yticks(range(car_rental_data.shape[1]), car_rental_data.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %% [markdown]
# ### are we dropping any columns based on corr? Why is NaN

# %%
corr = car_rental_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# E:\Anaconda\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row2_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row3_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_10458cb8_8504_11ea_ade2_3ca067dc1b19row4_col11 {
#             background-color:  #3b4cc0;
#             color:  #f

# %% [markdown]
# # Extracting, converting the features

# %%
# Extracting year, month and date from pickup date
car_rental_data["PICKUP_DATE_YEAR"] = pd.DatetimeIndex(car_rental_data["PICKUP_DATE"]).year
car_rental_data["PICKUP_DATE_MONTH"] = pd.DatetimeIndex(car_rental_data["PICKUP_DATE"]).month
car_rental_data["PICKUP_DATE_DATE"] = pd.DatetimeIndex(car_rental_data["PICKUP_DATE"]).day

# %%
car_rental_data.columns
# Out:
# Index(['AVG_BEFORE_DAYS', 'AVG_FARE', 'CHANGE PERCENT', 'COLLECT_DATE',
#        'HOLIDAY', 'HOLIDAY AFTER', 'HOLIDAY BEFORE', 'LOR', 'MAX_FARE',
#        'MEDIAN_FARE', 'MIN_FARE', 'PICKUP_DATE', 'TIME BEFORE RENTAL',
#        'WEEKEND', 'CHANGE', 'PICKUP_DATE_YEAR', 'PICKUP_DATE_MONTH',
#        'PICKUP_DATE_DATE'],
#       dtype='object')

# %%
# converting car_type to one-hot encoded format
car_rental_data = pd.get_dummies(car_rental_data, columns = ["new_OUTSIPP"] , prefix = "OUTSIPP", drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-b25acf8cf040> in <module>
#       1 # converting car_type to one-hot encoded format
# ----> 2 car_rental_data = pd.get_dummies(car_rental_data, columns = ["new_OUTSIPP"] , prefix = "OUTSIPP", drop_first=True)
#
# E:\Anaconda\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     870             data_to_encode = data.select_dtypes(include=dtypes_to_encode)
#     871         else:
# --> 872             data_to_encode = data[columns]
#     873
#     874         # validate prefixes and separator to avoid silently dropping cols
#
# E:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# E:\Anaconda\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# E:\Anaconda\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# E:\Anaconda\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['new_OUTSIPP'], dtype='object')] are in the [columns]"

# %%
car_rental_data.head()

# %%
car_rental_data.columns

# %%
# Filtering features and creating a copy
classification_drop_features = ["AVG_FARE","COLLECT_DATE","LOR", 'MAX_FARE', 'MEDIAN_FARE',
       'MIN_FARE', 'PICKUP_DATE', 'TIME BEFORE RENTAL', "CHANGE PERCENT"]
classification_data = car_rental_data.copy()
classification_data.drop(columns = classification_drop_features, inplace=True)

# %%
classification_data.head()

# %% [markdown]
# ## Scaling data

# %%
classification_data.columns

# %%
# classification_data[["AVG_BEFORE_DAYS", "CHANGE PERCENT"]].head(20)
classification_data[["AVG_BEFORE_DAYS"]].head(20)

# %%
# Scaling AVG_BEFORE_DAYS and CHANGE PERCENT
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# classification_data[["AVG_BEFORE_DAYS", "CHANGE PERCENT"]] = scaler.fit_transform(classification_data[["AVG_BEFORE_DAYS", "CHANGE PERCENT"]])
classification_data[["AVG_BEFORE_DAYS"]] = scaler.fit_transform(classification_data[["AVG_BEFORE_DAYS"]])

# %%
# classification_data[["AVG_BEFORE_DAYS", "CHANGE PERCENT"]].head(20)
classification_data[["AVG_BEFORE_DAYS"]].head(20)

# %% [markdown]
# # Machine Learning - Random Forest

# %%
# Extracting columns
classification_columns = [x for x in classification_data.columns.to_list() if x != "CHANGE"]
X = classification_data[classification_columns]
y = classification_data["CHANGE"]

# %%
X_train = X[:int(X.shape[0]*0.7)]
X_test = X[int(X.shape[0]*0.7):]
y_train = y[:int(X.shape[0]*0.7)]
y_test = y[int(X.shape[0]*0.7):]

# %%
# Checking correct sort order for train test splits
print("Min train date:", min(X_train["PICKUP_DATE_YEAR"]*100 + X_train["PICKUP_DATE_MONTH"]))
print("Max train date:", max(X_train["PICKUP_DATE_YEAR"]*100 + X_train["PICKUP_DATE_MONTH"]))

# %%
# Importing
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, balanced_accuracy_score, make_scorer

# %%
# Default model
default = RandomForestClassifier(random_state=1)
default.fit(X_train, y_train)
default_pred = default.predict(X_test)
print("Accuracy for default Random Forest on CV data: ",accuracy_score(y_test,default_pred))
print()
print("Balanced Accuracy for default Random Forest on CV data: ",balanced_accuracy_score(y_test,default_pred))
print()
for x, y in zip(X_train.columns.tolist(), default.feature_importances_):
    print(x,round(y,2))
print()
print("AUC", roc_auc_score(y_test, default.predict_proba(X_test)[:,1]))

# %%
# %timeit
rfc = RandomForestClassifier(random_state=1)
# Setting grid parameters
n_estimators = [100, 200, 300, 500, 800]
max_depth = [None, 4, 5, 6, 7, 8, 9, 10]
max_features = ['auto', 'sqrt', 'log2']
# min_samples_split = [2, 5, 10, 15, 100]
# min_samples_leaf = [1, 2, 5, 10]
criterion = ['gini', 'entropy']


parameters = dict(n_estimators = n_estimators, max_depth = max_depth,
                  criterion = criterion, max_features = max_features)

gridF = GridSearchCV(estimator = rfc, param_grid = parameters, cv = 5, verbose = 1,
                      n_jobs = -1)
gridF.fit(X_train, y_train)

# %%
# Best parameters
gridF.best_params_

# %%
# Reinitializing the best model
best_model = RandomForestClassifier(random_state=1, criterion="entropy", max_depth=4, max_features="log2", 
                                   n_estimators=500)
best_model.fit(X_train,y_train)

# %%
pred = best_model.predict(X_test)
print("Accuracy for best Random Forest on CV data: ",accuracy_score(y_test,pred))

# %%
print("Balanced Accuracy for default Random Forest on CV data: ",balanced_accuracy_score(y_test,pred))

# %%
print("AUC", roc_auc_score(y_test, best_model.predict_proba(X_test)[:,1]))

# %%
for x, y in zip(X_train.columns.tolist(), best_model.feature_importances_):
    print(x,round(y,2))

# %% [markdown]
# ## Extracting the data for classification

# %%
classification_data = classification_data.reset_index(drop=True)
classification_data.to_csv("classification_data.csv")
